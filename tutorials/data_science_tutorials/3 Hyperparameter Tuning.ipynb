# %% [markdown]
# <center><img src="http://mdst.eecs.umich.edu/images/mdst-logo-circle.png" width=350></center>

# %% [markdown]
# Let's get the data loaded right away so that we don't have to think about it.

# %%
# %matplotlib inline
import pandas as pd
import matplotlib.pyplot as plt

train_df = pd.read_csv('./data/flint_train.csv')
test_df = pd.read_csv('./data/flint_test.csv')

dummy_columns = ['Owner_Type', 'Residential_Building_Style', 'USPS_Vacancy', 
                 'Building_Storeys', 'Rental', 'Use_Type', 'Prop_Class', 'Zoning', 'Future_Landuse', 'DRAFT_Zone',
                 'Housing_Condition_2012', 'Housing_Condition_2014','Hydrant_Type', 'Ward', 'PRECINCT', 'CENTRACT', 
                 'Commercial_Condition_2013','CENBLOCK', 'SL_Type', 'SL_Type2', 'SL_Lead', 'Homestead']

drop_columns = ['sample_id', 'google_add', 'parcel_id', 'Date_Submitted']

combined_df = train_df.append(test_df)

combined_df = combined_df.drop(drop_columns, axis=1)
combined_df = pd.get_dummies(combined_df, columns = dummy_columns)

train_df = combined_df[:len(train_df)]
test_df = combined_df[len(train_df):]

# The combining of the dataframes created an empty column for lead in test_df.  We drop it here.
test_df = test_df.drop('Lead_(ppb)', axis=1)

# %%
from sklearn.cross_validation import train_test_split

Ydata_r = train_df['Lead_(ppb)']
Ydata_c = train_df['Lead_(ppb)'] > 15
Xdata = train_df.drop('Lead_(ppb)', axis=1)

# We'll be starting with a regression problem, so split on Ydata_r

Xtrain, Xtest, Ytrain, Ytest = train_test_split(Xdata, Ydata_c)

# %% [markdown]
# # Hyperparameter Tuning
#
# In this tutorial we will discuss "tuning" a model from scikit-learn.  So far we have created several models to predict which homes in Flint have dangerous water in their pipes.  However, for the most part these models have been "vanilla."  In other words, we have been using them with only default parameter values.  For example

# %%
from sklearn.ensemble import RandomForestClassifier

rf = RandomForestClassifier()

rf.fit(Xtrain, Ytrain)
yhat1 = rf.predict_proba(Xtest)

# %%
from sklearn.metrics import roc_auc_score as roc
from sklearn.metrics import roc_curve

fig = plt.figure()
fig.set_size_inches(8,8)

fpr, tpr, _ = roc_curve(Ytest, yhat1[:,1])
plt.plot(fpr, tpr, label= 'Random Forest (area = %0.5f)' % roc(Ytest, yhat1[:,1]))

plt.plot([0, 1], [0, 1], 'k--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])

plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('ROC Curves for Service Line Classifiers')
plt.legend(loc="lower right")

plt.show()

# %% [markdown]
# This is a decent classifier.  However, if you remember last time we changed one of the parameters when we created the random forest object - the number of trees in the forest.  This was done as follows:

# %%
rf = RandomForestClassifier(n_estimators=1024, n_jobs=-1)
rf.fit(Xtrain, Ytrain)
yhat2 = rf.predict_proba(Xtest)

rf = RandomForestClassifier(n_estimators=1)
rf.fit(Xtrain, Ytrain)
yhat3 = rf.predict_proba(Xtest)

# %%
fig = plt.figure()
fig.set_size_inches(8,8)

fpr, tpr, _ = roc_curve(Ytest, yhat1[:,1])
plt.plot(fpr, tpr, label= 'Random Forest 1(area = %0.5f)' % roc(Ytest, yhat1[:,1]))

fpr, tpr, _ = roc_curve(Ytest, yhat2[:,1])
plt.plot(fpr, tpr, label= 'Random Forest 2(area = %0.5f)' % roc(Ytest, yhat2[:,1]))

fpr, tpr, _ = roc_curve(Ytest, yhat3[:,1])
plt.plot(fpr, tpr, label= 'Random Forest 3(area = %0.5f)' % roc(Ytest, yhat3[:,1]))

plt.plot([0, 1], [0, 1], 'k--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])

plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('ROC Curves for Service Line Classifiers')
plt.legend(loc="lower right")

plt.show()

# %% [markdown]
# Changing this one parameter can changed the score for our classifier.  One choice decreased the score, and another increased it.  What other parameters does a random forest have?

# %%
rf = RandomForestClassifier(n_estimators=10, 
                            criterion='gini', 
                            max_depth=None, 
                            min_samples_split=2, 
                            min_samples_leaf=1, 
                            min_weight_fraction_leaf=0.0, 
                            max_features='auto', 
                            max_leaf_nodes=None, 
                            bootstrap=True, 
                            oob_score=False, 
                            n_jobs=1, 
                            random_state=None, 
                            verbose=0, 
                            warm_start=False, 
                            class_weight=None)

# %%
# Change some of the parameters of the random forest model above, and then run the code below.
# Experiment to see if you can improve the roc score.

rf.fit(Xtrain, Ytrain)
yhat = rf.predict_proba(Xtest)
print(roc(Ytest, yhat[:,1]))
# Out:
# 0.619202844568

# %% [markdown]
# That's a lot.  What about a linear model?  Say, ridge regression?

# %%
from sklearn.linear_model import RidgeClassifier

ri = RidgeClassifier(alpha=1.0, 
                     fit_intercept=True, 
                     normalize=False,
                     copy_X=True, 
                     max_iter=None, 
                     tol=0.001, 
                     class_weight=None, 
                     solver='auto', 
                     random_state=None)

# %% [markdown]
# Not quite as many, but still a lot.  Normal human beings can't keep track of every parameter of every model.  Also, sotware evolves and can change.  There is no guarantee that if you learn all the parameters of all the models now that in a few years new parameters won't be introduced.  It is better to do what a typical mortal does - check the documentation.
#
# <a href="http://scikit-learn.org/stable/modules/generated/sklearn.ensemble.RandomForestClassifier.html">Random forest documentation</a>
#
# <a href="http://scikit-learn.org/stable/modules/generated/sklearn.linear_model.RidgeClassifier.html">Ridge regression documentation</a>
#
# So now we know that these parameters exist.  We know how to change them.  The next question: How should we choose them?  One way is to do an exhaustive search.  Rather than code one up ourselves, sklearn saves the day again.

# %%
from sklearn.grid_search import GridSearchCV


#GridSearchCV(estimator,            A model like random forest, linear regression, etc.
#            param_grid,            A dictionary of parameters to try
#            n_jobs=1,              Parallelize?
#            cv=None,               How many cross validation folds?
#            verbose=0,             How much do you want the function to talk to you?
#            error_score='raise')   What should the function do if a model breaks?

# %% [markdown]
# In your own words, explain what cross validation is and why you would use it.

# %% [markdown]
# We illustrate an example of using a grid search below:

# %%
# First decide what kind of model you want to use.  We'll stick with a random forest.
# Create the object without changing any parameters.
rf = RandomForestClassifier()

# Now, create a dictionary of parameters to try.
param_dict={'n_estimators':[32, 64, 128, 256],
            'criterion':['gini', 'entropy'],
            'min_samples_split':[2,4,6]}

# Create the grid search classifier with your desired parameters.
grid_search_clf = GridSearchCV(rf, param_dict, n_jobs=-1, cv=3, verbose=3)

# %%
# Now we can fit and predict like any other model.
grid_search_clf.fit(Xtrain, Ytrain)
# Out:
# Fitting 3 folds for each of 24 candidates, totalling 72 fits
# [CV] n_estimators=32, criterion=gini, min_samples_split=2 ............
# [CV] n_estimators=32, criterion=gini, min_samples_split=2 ............
# [CV] n_estimators=32, criterion=gini, min_samples_split=2 ............
# [CV] n_estimators=64, criterion=gini, min_samples_split=2 ............
# [CV] n_estimators=64, criterion=gini, min_samples_split=2 ............
# [CV] n_estimators=64, criterion=gini, min_samples_split=2 ............
# [CV] n_estimators=128, criterion=gini, min_samples_split=2 ...........
# [CV] n_estimators=128, criterion=gini, min_samples_split=2 ...........
# [CV]  n_estimators=32, criterion=gini, min_samples_split=2, score=0.905653 -   0.6s
# [CV] n_estimators=128, criterion=gini, min_samples_split=2 ...........
# [CV]  n_estimators=32, criterion=gini, min_samples_split=2, score=0.905235 -   0.6s
# [CV] n_estimators=256, criterion=gini, min_samples_split=2 ...........
# [CV]  n_estimators=32, criterion=gini, min_samples_split=2, score=0.914373 -   0.6s
# [CV] n_estimators=256, criterion=gini, min_samples_split=2 ...........
# [CV]  n_estimators=64, criterion=gini, min_samples_split=2, score=0.907563 -   1.1s
# [CV] n_estimators=256, criterion=gini, min_samples_split=2 ...........
# [CV]  n_estimators=64, criterion=gini, min_samples_split=2, score=0.907528 -   1.2s
# [CV]  n_estimators=64, criterion=gini, min_samples_split=2, score=0.914373 -   1.1s
# [CV] n_estimators=32, criterion=gini, min_samples_split=4 ............
# [CV] n_estimators=32, criterion=gini, min_samples_split=4 ............
# [CV]  n_estimators=32, criterion=gini, min_samples_split=4, score=0.913642 -   0.5s
# [CV]  n_estimators=32, criterion=gini, min_samples_split=4, score=0.914057 -   0.5s
# [CV] n_estimators=32, criterion=gini, min_samples_split=4 ............
# [CV] n_estimators=64, criterion=gini, min_samples_split=4 ............
# [CV]  n_estimators=32, criterion=gini, min_samples_split=4, score=0.915520 -   0.5s
# [CV]  n_estimators=128, criterion=gini, min_samples_split=2, score=0.907181 -   2.2s
# [CV] n_estimators=64, criterion=gini, min_samples_split=4 ............
# [CV]  n_estimators=128, criterion=gini, min_samples_split=2, score=0.908292 -   2.2s
# [CV] n_estimators=64, criterion=gini, min_samples_split=4 ............
# [CV] n_estimators=128, criterion=gini, min_samples_split=4 ...........
# [CV]  n_estimators=128, criterion=gini, min_samples_split=2, score=0.916284 -   2.2s
# [CV] n_estimators=128, criterion=gini, min_samples_split=4 ...........
# [CV]  n_estimators=64, criterion=gini, min_samples_split=4, score=0.912529 -   1.1s
# [CV] n_estimators=128, criterion=gini, min_samples_split=4 ...........
# [CV]  n_estimators=64, criterion=gini, min_samples_split=4, score=0.916667 -   1.0s
# [CV] n_estimators=256, criterion=gini, min_samples_split=4 ...........
# [CV]  n_estimators=64, criterion=gini, min_samples_split=4, score=0.913259 -   1.1s
# [CV] n_estimators=256, criterion=gini, min_samples_split=4 ...........
# [CV]  n_estimators=128, criterion=gini, min_samples_split=4, score=0.913675 -   2.0s
# [CV] n_estimators=256, criterion=gini, min_samples_split=4 ...........
# [Parallel(n_jobs=-1)]: Done  16 tasks      | elapsed:    4.6s
# [CV]  n_estimators=128, criterion=gini, min_samples_split=4, score=0.915552 -   2.0s
# [CV] n_estimators=32, criterion=gini, min_samples_split=6 ............
# [CV]  n_estimators=256, criterion=gini, min_samples_split=2, score=0.909056 -   4.3s
# [CV] n_estimators=32, criterion=gini, min_samples_split=6 ............
# [CV]  n_estimators=256, criterion=gini, min_samples_split=2, score=0.907181 -   4.3s
# [CV]  n_estimators=128, criterion=gini, min_samples_split=4, score=0.917813 -   1.9s
# [CV] n_estimators=32, criterion=gini, min_samples_split=6 ............
# [CV] n_estimators=64, criterion=gini, min_samples_split=6 ............
# [CV]  n_estimators=32, criterion=gini, min_samples_split=6, score=0.917876 -   0.5s
# [CV] n_estimators=64, criterion=gini, min_samples_split=6 ............
# [CV]  n_estimators=32, criterion=gini, min_samples_split=6, score=0.918227 -   0.5s
# [CV] n_estimators=64, criterion=gini, min_samples_split=6 ............
# [CV]  n_estimators=32, criterion=gini, min_samples_split=6, score=0.917049 -   0.5s
# [CV]  n_estimators=256, criterion=gini, min_samples_split=2, score=0.916284 -   4.3s
# [CV] n_estimators=128, criterion=gini, min_samples_split=6 ...........
# [CV] n_estimators=128, criterion=gini, min_samples_split=6 ...........
# [CV]  n_estimators=64, criterion=gini, min_samples_split=6, score=0.917876 -   1.0s
# [CV] n_estimators=128, criterion=gini, min_samples_split=6 ...........
# [CV]  n_estimators=64, criterion=gini, min_samples_split=6, score=0.917463 -   1.0s
# [CV] n_estimators=256, criterion=gini, min_samples_split=6 ...........
# [CV]  n_estimators=64, criterion=gini, min_samples_split=6, score=0.917431 -   1.0s
# [CV] n_estimators=256, criterion=gini, min_samples_split=6 ...........
# [CV]  n_estimators=256, criterion=gini, min_samples_split=4, score=0.914788 -   3.9s
# [CV] n_estimators=256, criterion=gini, min_samples_split=6 ...........
# [CV]  n_estimators=128, criterion=gini, min_samples_split=6, score=0.918227 -   1.9s
# [CV]  n_estimators=256, criterion=gini, min_samples_split=4, score=0.915584 -   3.9s
# [CV] n_estimators=32, criterion=entropy, min_samples_split=2 .........
# [CV] n_estimators=32, criterion=entropy, min_samples_split=2 .........
# [CV]  n_estimators=128, criterion=gini, min_samples_split=6, score=0.917494 -   2.0s
# [CV] n_estimators=32, criterion=entropy, min_samples_split=2 .........
# [CV]  n_estimators=128, criterion=gini, min_samples_split=6, score=0.919343 -   1.9s
# [CV] n_estimators=64, criterion=entropy, min_samples_split=2 .........
# [CV]  n_estimators=32, criterion=entropy, min_samples_split=2, score=0.909091 -   0.6s
# [CV] n_estimators=64, criterion=entropy, min_samples_split=2 .........
# [CV]  n_estimators=32, criterion=entropy, min_samples_split=2, score=0.909438 -   0.6s
# [CV]  n_estimators=32, criterion=entropy, min_samples_split=2, score=0.914373 -   0.5s
# [CV] n_estimators=64, criterion=entropy, min_samples_split=2 .........
# [CV] n_estimators=128, criterion=entropy, min_samples_split=2 ........
# [CV]  n_estimators=256, criterion=gini, min_samples_split=4, score=0.917049 -   3.9s
# [CV] n_estimators=128, criterion=entropy, min_samples_split=2 ........
# [CV]  n_estimators=64, criterion=entropy, min_samples_split=2, score=0.907563 -   1.2s
# [CV] n_estimators=128, criterion=entropy, min_samples_split=2 ........
# [CV]  n_estimators=64, criterion=entropy, min_samples_split=2, score=0.907910 -   1.1s
# [CV] n_estimators=256, criterion=entropy, min_samples_split=2 ........
# [CV]  n_estimators=64, criterion=entropy, min_samples_split=2, score=0.915138 -   1.1s
# [CV] n_estimators=256, criterion=entropy, min_samples_split=2 ........
# [CV]  n_estimators=256, criterion=gini, min_samples_split=6, score=0.918227 -   3.7s
# [CV]  n_estimators=256, criterion=gini, min_samples_split=6, score=0.918258 -   3.8s
# [CV] n_estimators=256, criterion=entropy, min_samples_split=2 ........
# [CV] n_estimators=32, criterion=entropy, min_samples_split=4 .........
# [CV]  n_estimators=128, criterion=entropy, min_samples_split=2, score=0.908327 -   2.2s
# [CV] n_estimators=32, criterion=entropy, min_samples_split=4 .........
# [CV]  n_estimators=128, criterion=entropy, min_samples_split=2, score=0.908674 -   2.2s
# [CV] n_estimators=32, criterion=entropy, min_samples_split=4 .........
# [CV]  n_estimators=32, criterion=entropy, min_samples_split=4, score=0.912495 -   0.5s
# [CV]  n_estimators=32, criterion=entropy, min_samples_split=4, score=0.911001 -   0.6s
# [CV] n_estimators=64, criterion=entropy, min_samples_split=4 .........
# [CV] n_estimators=64, criterion=entropy, min_samples_split=4 .........
# [CV]  n_estimators=256, criterion=gini, min_samples_split=6, score=0.918578 -   3.7s
# [CV] n_estimators=64, criterion=entropy, min_samples_split=4 .........
# [CV]  n_estimators=32, criterion=entropy, min_samples_split=4, score=0.918578 -   0.6s
# [CV] n_estimators=128, criterion=entropy, min_samples_split=4 ........
# [CV]  n_estimators=128, criterion=entropy, min_samples_split=2, score=0.915520 -   2.2s
# [CV] n_estimators=128, criterion=entropy, min_samples_split=4 ........
# [CV]  n_estimators=64, criterion=entropy, min_samples_split=4, score=0.913259 -   1.1s
# [CV] n_estimators=128, criterion=entropy, min_samples_split=4 ........
# [CV]  n_estimators=64, criterion=entropy, min_samples_split=4, score=0.913293 -   1.1s
# [CV] n_estimators=256, criterion=entropy, min_samples_split=4 ........
# [CV]  n_estimators=64, criterion=entropy, min_samples_split=4, score=0.917049 -   1.0s
# [CV] n_estimators=256, criterion=entropy, min_samples_split=4 ........
# [CV]  n_estimators=128, criterion=entropy, min_samples_split=4, score=0.912147 -   2.1s
# [CV] n_estimators=256, criterion=entropy, min_samples_split=4 ........
# [CV]  n_estimators=128, criterion=entropy, min_samples_split=4, score=0.912495 -   2.1s
# [CV] n_estimators=32, criterion=entropy, min_samples_split=6 .........
# [CV]  n_estimators=256, criterion=entropy, min_samples_split=2, score=0.909056 -   4.3s
# [CV] n_estimators=32, criterion=entropy, min_samples_split=6 .........
# [CV]  n_estimators=256, criterion=entropy, min_samples_split=2, score=0.906799 -   4.5s
# [CV] n_estimators=32, criterion=entropy, min_samples_split=6 .........
# [CV]  n_estimators=32, criterion=entropy, min_samples_split=6, score=0.915584 -   0.6s
# [CV]  n_estimators=128, criterion=entropy, min_samples_split=4, score=0.917049 -   2.1s
# [CV] n_estimators=64, criterion=entropy, min_samples_split=6 .........
# [CV]  n_estimators=32, criterion=entropy, min_samples_split=6, score=0.917463 -   0.6s
# [CV] n_estimators=64, criterion=entropy, min_samples_split=6 .........
# [CV] n_estimators=64, criterion=entropy, min_samples_split=6 .........
# [CV]  n_estimators=32, criterion=entropy, min_samples_split=6, score=0.917431 -   0.6s
# [CV] n_estimators=128, criterion=entropy, min_samples_split=6 ........
# [CV]  n_estimators=256, criterion=entropy, min_samples_split=2, score=0.915520 -   4.4s
# [CV] n_estimators=128, criterion=entropy, min_samples_split=6 ........
# [CV]  n_estimators=64, criterion=entropy, min_samples_split=6, score=0.917112 -   1.1s
# [CV]  n_estimators=64, criterion=entropy, min_samples_split=6, score=0.918960 -   1.0s
# [CV] n_estimators=128, criterion=entropy, min_samples_split=6 ........
# [CV]  n_estimators=64, criterion=entropy, min_samples_split=6, score=0.916699 -   1.1s
# [CV] n_estimators=256, criterion=entropy, min_samples_split=6 ........
# [CV] n_estimators=256, criterion=entropy, min_samples_split=6 ........
# [CV]  n_estimators=256, criterion=entropy, min_samples_split=4, score=0.912147 -   4.3s
# [CV]  n_estimators=256, criterion=entropy, min_samples_split=4, score=0.914024 -   4.2s
# [CV] n_estimators=256, criterion=entropy, min_samples_split=6 ........
# [CV]  n_estimators=128, criterion=entropy, min_samples_split=6, score=0.917876 -   2.1s
# [CV]  n_estimators=128, criterion=entropy, min_samples_split=6, score=0.918227 -   2.0s
# [CV]  n_estimators=128, criterion=entropy, min_samples_split=6, score=0.919725 -   1.9s
# [CV]  n_estimators=256, criterion=entropy, min_samples_split=4, score=0.918196 -   3.9s
# [CV]  n_estimators=256, criterion=entropy, min_samples_split=6, score=0.916348 -   3.1s
# [CV]  n_estimators=256, criterion=entropy, min_samples_split=6, score=0.918991 -   3.0s
# [CV]  n_estimators=256, criterion=entropy, min_samples_split=6, score=0.919725 -   2.5s
# [Parallel(n_jobs=-1)]: Done  72 out of  72 | elapsed:   19.0s finished
# GridSearchCV(cv=3, error_score='raise',
#        estimator=RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#             max_depth=None, max_features='auto', max_leaf_nodes=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, n_estimators=10, n_jobs=1,
#             oob_score=False, random_state=None, verbose=0,
#             warm_start=False),
#        fit_params={}, iid=True, n_jobs=-1,
#        param_grid={'n_estimators': [32, 64, 128, 256], 'criterion': ['gini', 'entropy'], 'min_samples_split': [2, 4, 6]},
#        pre_dispatch='2*n_jobs', refit=True, scoring=None, verbose=3)

# %%
yhat_g = grid_search_clf.predict_proba(Xtest)

# Which parameters worked the best?
print(grid_search_clf.best_params_)
# Out:
# {'n_estimators': 128, 'criterion': 'entropy', 'min_samples_split': 6}

# %%
fig = plt.figure()
fig.set_size_inches(8,8)

fpr, tpr, _ = roc_curve(Ytest, yhat_g[:,1])
plt.plot(fpr, tpr, label= 'Grid Search (area = %0.5f)' % roc(Ytest, yhat_g[:,1]))

fpr, tpr, _ = roc_curve(Ytest, yhat2[:,1])
plt.plot(fpr, tpr, label= 'Random Forest 2(area = %0.5f)' % roc(Ytest, yhat2[:,1]))

plt.plot([0, 1], [0, 1], 'k--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])

plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('ROC Curves for Service Line Classifiers')
plt.legend(loc="lower right")

plt.show()

# %% [markdown]
# What are some of the potential issues you could run into using GridSearchCV?

# %% [markdown]
# This is a straightforward way to explore the parameter space of our models.  However, it is not necessarily the most efficient.  For high dimensional parameter spaces, it has been observed that RANDOM sampling of the parameter space works better.  Fortunately sklearn has a function to do that as well:  RandomizedSearchCV.  It is a little trickier to use so I will omit it for now.  I highly recommend you look over the documentation <a href="http://scikit-learn.org/0.15/modules/generated/sklearn.grid_search.RandomizedSearchCV.html">here</a>
